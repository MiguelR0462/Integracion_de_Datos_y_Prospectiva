# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelR0462/Integracion_de_Datos_y_Prospectiva/blob/main/Clase_1_Caracterizacion_de_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# montamos el google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# cargamos las librerias necesarias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargamos el archivo
path = '/content/drive/MyDrive/Universidad/Semestre 8/Integracion de Datos y Prospectiva/Archivos/RO - Evergreen.xlsx'
df = pd.read_excel(path)
df
# Out:
#       Semana  Transacción Mensuales (Mes)  Valor Transado (MUSD)  \
# 0          1                           44              27.145501
# 1          2                          194              68.447342
# 2          3                          217              20.111928
# 3          4                          278              60.008094
# 4          5                          286              63.007004
# ...      ...                          ...                    ...
# 2799    2800                           39              23.886707
# 2800    2801                          319              40.392800
# 2801    2802                          495              19.572457
# 2802    2803                          197              14.077296
# 2803    2804                          218              46.358165
#
#       Eventos (Mes)  Severidad (KUSD)  \
# 0                 4          2.867141
# 1                20          6.420941
# 2                22          2.174181
# ...
